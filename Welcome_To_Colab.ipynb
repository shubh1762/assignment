# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh1762/assignment/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary =[2000,3000,4000,5000]
plt.plot(x_cgpa,y_salary,"o--g")
plt.plot(x_cgpa,y_salary)
plt.xlabel("cgpa")
plt.ylabel("salary")
plt.show()
